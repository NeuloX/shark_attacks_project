# %%
import os
import pandas as pd
import re
import psycopg2
from pdfminer.high_level import extract_text
shark_data = pd.read_csv("clean_shark_dataV4.csv")
shark_data
# Out:
#      case_number         date  year         type             country  \
# 0     2020.10.09     9-Oct-20  2020   Unprovoked           AUSTRALIA
# 1     2020.10.07     7-Oct-20  2020   Unprovoked                 USA
# 2     2020.10.04     4-Oct-20  2020   Unprovoked           AUSTRALIA
# 3     2020.09.21    21-Sep-20  2020  Not Defined                 USA
# 4     2020.09.20    20-Sep-20  2020   Unprovoked                 USA
# ...          ...          ...   ...          ...                 ...
# 6557     ND.0005  Before 1903  1903   Unprovoked           AUSTRALIA
# 6558     ND.0004  Before 1903  1903   Unprovoked           AUSTRALIA
# 6559     ND.0003    1900-1905  1903   Unprovoked                 USA
# 6560     ND.0002    1883-1889  1883   Unprovoked              PANAMA
# 6561     ND.0001    1845-1853  1843   Unprovoked  CEYLON (SRI LANKA)
#
#                    area                                           location  \
# ...

# %%
from sqlalchemy import create_engine

username = "roiwimyplsisvt"
password ="7a68b737557eb6182ab100fabbf6e4e8e080b5132ca425d81b9fbaf9eb737c0b"

engine = create_engine(f'postgres://roiwimyplsisvt:7a68b737557eb6182ab100fabbf6e4e8e080b5132ca425d81b9fbaf9eb737c0b@ec2-52-205-61-60.compute-1.amazonaws.com:5432/d5ug7elorgd6et')
connection = engine.connect()
shark_data.to_sql('shark_attacks', con=engine, if_exists='append', index=False)
print ("upload Done!")
